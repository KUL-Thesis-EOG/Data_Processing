# %%
import pandas as pd
import plotly.express as px

# %%
_files = pd.read_parquet("./results_windowed/nicolas_eog_complexity_windowed/processing_summary.parquet")

# %%
df_eog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1698061 entries, 2025-03-27 14:03:10.785000 to 2025-03-27 16:46:33.355000
# Data columns (total 11 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   slider.response      float64
#  1   vertical_filtered    float64
#  2   horizontal_filtered  float64
#  3   AXCPT_resp.rt        float64
#  4   AXCPT_resp.corr      float64
#  5   NBack_resp_2.rt      float64
#  6   NBack_resp_2.corr    float64
#  7   key_resp_14.rt       float64
#  8   key_resp_14.corr     float64
#  9   MROT_resp.rt         float64
#  10  MROT_resp.corr       float64
# dtypes: float64(11)
# memory usage: 155.5 MB

# %%
df = pd.DataFrame()
for x in _files["saved_files_list"][0]:
    df[x.removesuffix(".parquet")] = pd.read_parquet(f"results_windowed/sofia_eog_complexity_windowed/{x}")
# df = df.dropna(axis=1)

# %%
df
# Out:
#       Mean_horizontal_filtered  Median_horizontal_filtered  \
# 0                     0.025377                    0.013074
# 1                     0.009207                    0.007658
# 2                    -0.018881                    0.001780
# 3                     0.009265                    0.010028
# 4                    -0.001551                   -0.001893
# ...                        ...                         ...
# 8476                 -0.090961                   -0.043258
# 8477                 -0.020419                   -0.007967
# 8478                  0.044475                    0.041090
# 8479                  0.023379                    0.009382
# 8480                  0.004809                    0.002178
#
#       Variance_horizontal_filtered  Skewness_horizontal_filtered  \
# 0                         0.001664                     -0.129266
# 1                         0.001018                     -0.915624
# ...

# %%
df.to_parquet("nicolas_features.parquet")
